# %% [markdown]
# # This project is meant to predict sales for the thousands of product families sold at Favorita (https://www.kaggle.com/c/favorita-grocery-sales-forecasting).

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import linear_model

from scipy.stats import norm, pearsonr
from math import log
from statistics import mean, variance, stdev

from scipy import stats
from sklearn.impute import SimpleImputer

import datetime
# install slim version (default)
# !pip install pycaret
from sklearn.preprocessing import LabelEncoder

# Importing the relevant libraries
import IPython.display
import json
import pandas as pd
import seaborn as sns
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import numpy as np
from matplotlib import pyplot as plt
color = sns.color_palette()

# D3 modules
from IPython.core.display import display, HTML, Javascript
from string import Template
# Out:
# Requirement already satisfied: pycaret in c:\users\19144\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (0.10.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (6.3.0)
# Requirement already satisfied: sktime>=0.16.1 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (0.17.1)
# Requirement already satisfied: cloudpickle in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: tbats>=1.1.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (1.1.2)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: xxhash in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (3.2.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (5.5.0)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (0.8.3.2)
# Requirement already satisfied: numpy<1.25,>=1.21 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (1.21.6)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (3.3.5)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (3.5.2)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: numba>=0.55.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (0.55.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: jinja2>=1.2 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (1.2.2)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (2.6.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (0.13.2)
# Requirement already satisfied: schemdraw>=0.14 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (0.16)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (7.31.1)
# Requirement already satisfied: scipy<2.0.0 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (1.9.1)
# Requirement already satisfied: pyod>=1.0.8 in c:\users\19144\anaconda3\lib\site-packages (from pycaret) (1.0.9)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\19144\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: packaging in c:\users\19144\anaconda3\lib\site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\19144\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\19144\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\19144\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: backcall in c:\users\19144\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\19144\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (63.4.1)
# Requirement already satisfied: decorator in c:\users\19144\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\19144\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\19144\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pygments in c:\users\19144\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: pickleshare in c:\users\19144\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in c:\users\19144\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: colorama in c:\users\19144\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\19144\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\19144\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\19144\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\19144\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.2)
# Requirement already satisfied: wheel in c:\users\19144\anaconda3\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\19144\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\19144\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\19144\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\19144\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\19144\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\19144\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\19144\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.16.0)
# Requirement already satisfied: jupyter_core in c:\users\19144\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.11.1)
# Requirement already satisfied: fastjsonschema in c:\users\19144\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\19144\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\19144\anaconda3\lib\site-packages (from pandas<1.6.0,>=1.3.0->pycaret) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\19144\anaconda3\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\19144\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.8.10)
# Requirement already satisfied: trace-updater>=0.0.8 in c:\users\19144\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in c:\users\19144\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.9.3)
# Requirement already satisfied: jupyter-dash>=0.4.2 in c:\users\19144\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\19144\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: urllib3 in c:\users\19144\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.11)
# Requirement already satisfied: six in c:\users\19144\anaconda3\lib\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\19144\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\19144\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\19144\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\19144\anaconda3\lib\site-packages (from sktime>=0.16.1->pycaret) (1.2.13)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\19144\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.1.2)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\19144\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\19144\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\19144\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\19144\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\19144\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\19144\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\19144\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: nest-asyncio in c:\users\19144\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\19144\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\19144\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\19144\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\19144\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: retrying in c:\users\19144\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: ansi2html in c:\users\19144\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: wcwidth in c:\users\19144\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\19144\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: pywin32>=1.0 in c:\users\19144\anaconda3\lib\site-packages (from jupyter_core->nbformat>=4.2.0->pycaret) (302)
# Requirement already satisfied: click>=5.1 in c:\users\19144\anaconda3\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\19144\anaconda3\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\19144\anaconda3\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: entrypoints in c:\users\19144\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: prometheus-client in c:\users\19144\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: argon2-cffi in c:\users\19144\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\19144\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\19144\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\19144\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: testpath in c:\users\19144\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: defusedxml in c:\users\19144\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\19144\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\19144\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\19144\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: bleach in c:\users\19144\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\19144\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\19144\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\19144\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\19144\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\19144\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\19144\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\19144\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\19144\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
holidays_events   = pd.read_csv("holidays_events.csv")
oil               = pd.read_csv("oil.csv")
sample_submission = pd.read_csv("sample_submission.csv")
stores            = pd.read_csv("stores.csv")
test              = pd.read_csv("test.csv")
train             = pd.read_csv("train.csv")
transactions      = pd.read_csv("transactions.csv")
items             = pd.read_csv("items.csv")

# %%
#View values in each csv file
holidays_events.dtypes
# Out:
# date           object
# type           object
# locale         object
# locale_name    object
# description    object
# transferred      bool
# dtype: object

# %%
oil.dtypes
# Out:
# date           object
# dcoilwtico    float64
# dtype: object

# %%
sample_submission.dtypes
# Out:
# id         int64
# sales    float64
# dtype: object

# %%
stores.dtypes
# Out:
# store_nbr     int64
# city         object
# state        object
# type         object
# cluster       int64
# dtype: object

# %%
test.dtypes
# Out:
# id              int64
# date           object
# store_nbr       int64
# onpromotion      bool
# dtype: object

# %%
train.dtypes
# Out:
# id              int64
# date           object
# store_nbr       int64
# item_nbr        int64
# unit_sales    float64
# dtype: object

# %%
transactions.dtypes
# Out:
# date            object
# store_nbr        int64
# transactions     int64
# dtype: object

# %%
#Preprocessing
#Are there any missing values?
print('Missing Values %')
print("-"*25)
print(round(holidays_events.isnull().sum()/holidays_events.shape[0]*100,2))
# Out:
# Missing Values %
# -------------------------
# date           0.0
# type           0.0
# locale         0.0
# locale_name    0.0
# description    0.0
# transferred    0.0
# dtype: float64

# %%
#Are there any missing values?
print('Missing Values %')
print("-"*25)
print(round(oil.isnull().sum()/oil.shape[0]*100,2))
# Out:
# Missing Values %
# -------------------------
# date          0.00
# dcoilwtico    3.53
# dtype: float64

# %%
#Impute data for dcoilwtico
# handling the missing data and replace missing values with nan from numpy and replace with mean of all the other values
#Filling Null Values for larger missing data
oil['dcoilwtico'].fillna('None',inplace=True)

# %%
#Are there any missing values?
print('Missing Values %')
print("-"*25)
print(round(oil.isnull().sum()/oil.shape[0]*100,2))
# Out:
# Missing Values %
# -------------------------
# date          0.0
# dcoilwtico    0.0
# dtype: float64

# %%
#Are there any missing values?
print('Missing Values %')
print("-"*25)
print(round(stores.isnull().sum()/stores.shape[0]*100,2))
# Out:
# Missing Values %
# -------------------------
# store_nbr    0.0
# city         0.0
# state        0.0
# type         0.0
# cluster      0.0
# dtype: float64

# %%
#Are there any missing values?
print('Missing Values %')
print("-"*25)
print(round(test.isnull().sum()/test.shape[0]*100,2))
# Out:
# Missing Values %
# -------------------------
# id             0.0
# date           0.0
# store_nbr      0.0
# onpromotion    0.0
# dtype: float64

# %%
#Are there any missing values?
print('Missing Values %')
print("-"*25)
print(round(transactions.isnull().sum()/transactions.shape[0]*100,2))
# Out:
# Missing Values %
# -------------------------
# date            0.0
# store_nbr       0.0
# transactions    0.0
# dtype: float64

# %% [markdown]
# # Since there aren't really any missing values, the next step is to dummy code categorical variables

# %%
#LABEL ENCODE DEVELOPER PUBLISHER YEAR_OF RELEASE AND PLATFORM

#Stores data frame

# type label encoder
type_LE=LabelEncoder()
stores.type=type_LE.fit_transform(stores.type)

# state label encoder
state_LE=LabelEncoder()
stores.state=state_LE.fit_transform(stores.state)

# city label encoder
city_LE=LabelEncoder()
stores.city=city_LE.fit_transform(stores.city)

#holidays_events data frame 

# locale label encoder
locale_LE=LabelEncoder()
holidays_events.locale=locale_LE.fit_transform(holidays_events.locale)

# locale_name label encoder
locale_name_LE=LabelEncoder()
holidays_events.locale_name=locale_name_LE.fit_transform(holidays_events.locale_name)

# description label encoder
description_LE=LabelEncoder()
holidays_events.description=description_LE.fit_transform(holidays_events.description)

# transferred label encoder
transferred_LE=LabelEncoder()
holidays_events.transferred=transferred_LE.fit_transform(holidays_events.transferred)

#test data frame 

# family label encoder
#family_LE=LabelEncoder()
#test.family=family_LE.fit_transform(test.family)

#train data frame 

#family label encoder
#family_LE=LabelEncoder()
#train.family=family_LE.fit_transform(train.family)

# %%
# !pip install holidays
from datetime import date
import holidays
  
# Select country
ec_holidays = holidays.Ecuador()
  
# Print all the holidays in UnitedKingdom in year 2018
for ptr in holidays.Ecuador(years = 2012).items():
    print(ptr)
# Out:
# Requirement already satisfied: holidays in c:\users\19144\anaconda3\lib\site-packages (0.23)
# Requirement already satisfied: korean-lunar-calendar in c:\users\19144\anaconda3\lib\site-packages (from holidays) (0.3.1)
# Requirement already satisfied: convertdate>=2.3.0 in c:\users\19144\anaconda3\lib\site-packages (from holidays) (2.4.0)
# Requirement already satisfied: hijri-converter in c:\users\19144\anaconda3\lib\site-packages (from holidays) (2.2.4)
# Requirement already satisfied: python-dateutil in c:\users\19144\anaconda3\lib\site-packages (from holidays) (2.8.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\users\19144\anaconda3\lib\site-packages (from convertdate>=2.3.0->holidays) (0.5.12)
# Requirement already satisfied: six>=1.5 in c:\users\19144\anaconda3\lib\site-packages (from python-dateutil->holidays) (1.16.0)
# (datetime.date(2012, 1, 1), 'Año Nuevo')
# (datetime.date(2012, 2, 20), 'Carnaval')
# (datetime.date(2012, 2, 21), 'Carnaval')
# (datetime.date(2012, 4, 6), 'Viernes Santo')
# (datetime.date(2012, 5, 1), 'Día del Trabajo')
# (datetime.date(2012, 5, 24), 'Batalla de Pichincha')
# (datetime.date(2012, 8, 10), 'Primer Grito de Independencia')
# (datetime.date(2012, 10, 9), 'Independencia de Guayaquil')
# (datetime.date(2012, 11, 2), 'Día de los Difuntos')
# (datetime.date(2012, 11, 3), 'Independencia de Cuenca')
# (datetime.date(2012, 12, 25), 'Día de Navidad')

# %%
holidays_events.head(3)
# Out:
#          date     type  locale  locale_name  description  transferred
# 0  2012-03-02  Holiday       0           15           25            0
# 1  2012-04-01  Holiday       2            2           54            0
# 2  2012-04-12  Holiday       0            3           18            0

# %%
plt.style.use('seaborn-white')
# plt.style.use('dark_background')
holiday_local_type = holidays_events.groupby(['locale_name', 'type']).size()
holiday_local_type.unstack().plot(kind='bar',stacked=True, colormap= 'magma_r', figsize=(12,10),  grid=False)
plt.title('Stacked Barplot of locale name against event type')
plt.ylabel('Count of entries')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#Find correlations here and produce a heatmap
corr = stores.corr(), oil.corr()
print(corr)
# Out:
# (           store_nbr      city     state      type   cluster
# store_nbr   1.000000 -0.318438 -0.206680 -0.398412 -0.059284
# city       -0.318438  1.000000  0.511076 -0.125436  0.093806
# state      -0.206680  0.511076  1.000000 -0.262662  0.169536
# type       -0.398412 -0.125436 -0.262662  1.000000 -0.268419
# cluster    -0.059284  0.093806  0.169536 -0.268419  1.000000, Empty DataFrame
# Columns: []
# Index: [])

# %%
trace = go.Scatter(
     name='Oil prices',
     x=oil['date'],
     y=oil['dcoilwtico'].dropna(),
     mode='lines',
     line=dict(color='rgb(20, 15, 200, 0.8)'),
     #fillcolor='rgba(68, 68, 68, 0.3)',
     fillcolor='rgba(0, 0, 216, 0.3)',
     fill='tonexty' )

data = [trace]

layout = go.Layout(
     yaxis=dict(title='Daily Oil price'),
     title='Daily oil prices from Jan 2013 till July 2017',
     showlegend = False)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='pandas-time-series-error-bars')
# Out:
# <div>                            <div id="85fa147f-2c7f-4d2c-ac53-189b0c34017d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85fa147f-2c7f-4d2c-ac53-189b0c34017d")) {                    Plotly.newPlot(                        "85fa147f-2c7f-4d2c-ac53-189b0c34017d",                        [{"fill":"tonexty","fillcolor":"rgba(0, 0, 216, 0.3)","line":{"color":"rgb(20, 15, 200, 0.8)"},"mode":"lines","name":"Oil prices","x":["2013-01-01","2013-01-02","2013-01-03","2013-01-04","2013-01-07","2013-01-08","2013-01-09","2013-01-10","2013-01-11","2013-01-14","2013-01-15","2013-01-16","2013-01-17","2013-01-18","2013-01-21","2013-01-22","2013-01-23","2013-01-24","2013-01-25","2013-01-28","2013-01-29","2013-01-30","2013-01-31","2013-02-01","2013-02-04","2013-02-05","2013-02-06","2013-02-07","2013-02-08","2013-02-11","2013-02-12","2013-02-13","2013-02-14","2013-02-15","2013-02-18","2013-02-19","2013-02-20","2013-02-21","2013-02-22","2013-02-25","2013-02-26","2013-02-27","2013-02-28","2013-03-01","2013-03-04","2013-03-05","2013-03-06","2013-03-07","2013-03-08","2013-03-11","2013-03-12","2013-03-13","2013-03-14","2013-03-15","2013-03-18","2013-03-19","2013-03-20","2013-03-21","2013-03-22","2013-03-25","2013-03-26","2013-03-27","2013-03-28","2013-03-29","2013-04-01","2013-04-02","2013-04-03","2013-04-04","2013-04-05","2013-04-08","2013-04-09","2013-04-10","2013-04-11","2013-04-12","2013-04-15","2013-04-16","2013-04-17","2013-04-18","2013-04-19","2013-04-22","2013-04-23","2013-04-24","2013-04-25","2013-04-26","2013-04-29","2013-04-30","2013-05-01","2013-05-02","2013-05-03","2013-05-06","2013-05-07","2013-05-08","2013-05-09","2013-05-10","2013-05-13","2013-05-14","2013-05-15","2013-05-16","2013-05-17","2013-05-20","2013-05-21","2013-05-22","2013-05-23","2013-05-24","2013-05-27","2013-05-28","2013-05-29","2013-05-30","2013-05-31","2013-06-03","2013-06-04","2013-06-05","2013-06-06","2013-06-07","2013-06-10","2013-06-11","2013-06-12","2013-06-13","2013-06-14","2013-06-17","2013-06-18","2013-06-19","2013-06-20","2013-06-21","2013-06-24","2013-06-25","2013-06-26","2013-06-27","2013-06-28","2013-07-01","2013-07-02","2013-07-03","2013-07-04","2013-07-05","2013-07-08","2013-07-09","2013-07-10","2013-07-11","2013-07-12","2013-07-15","2013-07-16","2013-07-17","2013-07-18","2013-07-19","2013-07-22","2013-07-23","2013-07-24","2013-07-25","2013-07-26","2013-07-29","2013-07-30","2013-07-31","2013-08-01","2013-08-02","2013-08-05","2013-08-06","2013-08-07","2013-08-08","2013-08-09","2013-08-12","2013-08-13","2013-08-14","2013-08-15","2013-08-16","2013-08-19","2013-08-20","2013-08-21","2013-08-22","2013-08-23","2013-08-26","2013-08-27","2013-08-28","2013-08-29","2013-08-30","2013-09-02","2013-09-03","2013-09-04","2013-09-05","2013-09-06","2013-09-09","2013-09-10","2013-09-11","2013-09-12","2013-09-13","2013-09-16","2013-09-17","2013-09-18","2013-09-19","2013-09-20","2013-09-23","2013-09-24","2013-09-25","2013-09-26","2013-09-27","2013-09-30","2013-10-01","2013-10-02","2013-10-03","2013-10-04","2013-10-07","2013-10-08","2013-10-09","2013-10-10","2013-10-11","2013-10-14","2013-10-15","2013-10-16","2013-10-17","2013-10-18","2013-10-21","2013-10-22","2013-10-23","2013-10-24","2013-10-25","2013-10-28","2013-10-29","2013-10-30","2013-10-31","2013-11-01","2013-11-04","2013-11-05","2013-11-06","2013-11-07","2013-11-08","2013-11-11","2013-11-12","2013-11-13","2013-11-14","2013-11-15","2013-11-18","2013-11-19","2013-11-20","2013-11-21","2013-11-22","2013-11-25","2013-11-26","2013-11-27","2013-11-28","2013-11-29","2013-12-02","2013-12-03","2013-12-04","2013-12-05","2013-12-06","2013-12-09","2013-12-10","2013-12-11","2013-12-12","2013-12-13","2013-12-16","2013-12-17","2013-12-18","2013-12-19","2013-12-20","2013-12-23","2013-12-24","2013-1 ...

# %%
# Finally plot the seaborn heatmap
plt.style.use('dark_background')
plt.figure(figsize=(15,12))
store_pivot = stores.dropna().pivot("store_nbr","cluster", "store_nbr")
ax = sns.heatmap(store_pivot, cmap='jet', annot=True, linewidths=0, linecolor='white')
plt.title('Store numbers and the clusters they are assigned to')
# Out:
# Text(0.5, 1.0, 'Store numbers and the clusters they are assigned to')

# %%
plt.style.use('seaborn-white')
type_cluster = stores.groupby(['type','cluster']).size()
type_cluster.unstack().plot(kind='bar',stacked=True, colormap= 'PuBu', figsize=(13,11),  grid=False)
plt.title('Stacked Barplot of Store types and their cluster distribution', fontsize=18)
plt.ylabel('Count of clusters in a particular store type', fontsize=16)
plt.xlabel('Store type', fontsize=16)
plt.show()

# %%
plt.style.use('seaborn-white')
city_cluster = stores.groupby(['city','type']).store_nbr.size()
city_cluster.unstack().plot(kind='bar',stacked=True, colormap= 'viridis', figsize=(13,11),  grid=False)
plt.title('Stacked Barplot of Store types opened for each city')
plt.ylabel('Count of stores for a particular city')
plt.show()

# %%
import datetime as dt
from sklearn.base import BaseEstimator, TransformerMixin

class prepare_data(BaseEstimator, TransformerMixin):
    def __init__(self):
        print("prepare_data -> init")
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        train_stores = X[0].merge(X[1], right_on = 'store_nbr', left_on='store_nbr')
        train_stores_oil = train_stores.merge(X[2], right_on='date', left_on='date')
        train_stores_oil_items = train_stores_oil.merge(X[3], right_on = 'item_nbr', left_on = 'item_nbr')
        train_stores_oil_items_transactions = train_stores_oil_items.merge(X[4], right_on = ['date', 'store_nbr'], left_on = ['date', 'store_nbr'])
        train_stores_oil_items_transactions_hol = train_stores_oil_items_transactions.merge(X[5], right_on = 'date', left_on = 'date')
        
        data_df = train_stores_oil_items_transactions_hol.copy(deep = True)
        
        # change the bool to int
        #data_df['onpromotion'] = data_df['onpromotion'].astype(int)
        data_df['transferred'] = data_df['transferred'].astype(int)

        # change the names
        data_df.rename(columns={'type_x': 'st_type', 'type_y': 'hol_type'}, inplace=True)

        # drop the id
        data_df.drop(['id'], axis=1, inplace=True)
        
        print(data_df.head())
        
        # handle date
        data_df['date'] = pd.to_datetime(data_df['date'])
        data_df['date'] = data_df['date'].map(dt.datetime.toordinal)
                
        return data_df

# %%
# split dataframe into numerical values, categorical values and date
class split_data(BaseEstimator, TransformerMixin):
    def __init__(self):
        print("split_data -> init")
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        # Get columns for each type         
        df_ = X.drop(['date'], axis = 1)
        cols = df_.columns
        num_cols = df_._get_numeric_data().columns
        cat_cols = list(set(cols) - set(num_cols))
        
        data_num_df = X[num_cols]
        data_cat_df = X[cat_cols]
        data_date_df = X['date']
        
        return data_num_df, data_cat_df, data_date_df

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

class process_data(BaseEstimator, TransformerMixin):
    def __init__(self):
        print("process_data -> init")
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        ### numerical data
        # impute nulls in numerical attributes
        imputer = SimpleImputer(strategy="mean", copy="true")
        num_imp = imputer.fit_transform(X[0])
        data_num_df = pd.DataFrame(num_imp, columns=X[0].columns, index=X[0].index)
        
        # apply standard scaling
        scaler = StandardScaler()
        scaler.fit(data_num_df)
        num_scaled = scaler.transform(data_num_df)
        data_num_df = pd.DataFrame(num_scaled, columns=X[0].columns, index=X[0].index)
        
        ### categorical data
        # one hot encoder
        cat_encoder = OneHotEncoder(sparse=False)
        data_cat_1hot = cat_encoder.fit_transform(X[1])
        
        # convert it to datafram with n*99 where n number of rows and 99 is no. of categories
        data_cat_df = pd.DataFrame(data_cat_1hot, columns=cat_encoder.get_feature_names()) #, index=X[1].index)
                
        return data_num_df, data_cat_df, X[2]

# %%
class join_df(BaseEstimator, TransformerMixin):
    def __init__(self):
        print("join_df -> init")
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        ### numerical data
        data_df = X[0].join(X[1])
        data_df = data_df.join(X[2])
        
        return data_df

# %%
# import libraries for metrics and reporting
from sklearn import metrics
from statsmodels.tools.eval_measures import rmse
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import learning_curve

def model_metrics(y_true, y_hypothesis, test='test data'): 
    print("metrics using {} ...".format(test))
    print('Mean Abs Error   MAE    : ', mean_absolute_error(y_true, y_hypothesis))
    print('Mean Sq  Error MSE      : ', mean_squared_error(y_true, y_hypothesis))
    print('Root Mean Sq Error RMSE : ', np.sqrt(mean_squared_error(y_true, y_hypothesis)))
    print('MAPE                    : ', np.mean(np.abs((y_true - y_pred) / y_true)) * 100)
    print('MPE                     : ', np.mean((y_true - y_pred) / y_true) * 100)
    print('r2 value                : ', r2_score(y_true, y_hypothesis))

    print('\n')
